# %% [markdown]
# ### Kafka Producer
# Produces Current DateTime stamp with a random count continously unless stopped.
# Produces to the topic <strong>Week9-Topic</strong>

# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt

#configuration
hostip = "kafka" #change me

topic = 'Session09-Topic1'


def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print(f'Message published successfully. Data: {value}')
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'], api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    while True:
        data = f'{dt.datetime.now().strftime("%X")} , {random.randrange(0,100)}'
        publish_message(producer, topic, 'parsed', data)
        #print(data)
        sleep(1)
# Out:
# Publishing records..
# Message published successfully. Data: 06:05:32 , 84
# Message published successfully. Data: 06:05:33 , 6
# Message published successfully. Data: 06:05:34 , 56
# Message published successfully. Data: 06:05:35 , 41
# Message published successfully. Data: 06:05:36 , 4
# Message published successfully. Data: 06:05:37 , 45
# Message published successfully. Data: 06:05:38 , 90
# Message published successfully. Data: 06:05:39 , 83
# Message published successfully. Data: 06:05:40 , 82
# Message published successfully. Data: 06:05:41 , 22
# Message published successfully. Data: 06:05:42 , 32
# Message published successfully. Data: 06:05:43 , 30
# Message published successfully. Data: 06:05:44 , 65
# Message published successfully. Data: 06:05:45 , 74
# Message published successfully. Data: 06:05:46 , 29
# Message published successfully. Data: 06:05:48 , 89
# Message published successfully. Data: 06:05:49 , 88
# Message published successfully. Data: 06:05:50 , 90
# Message published successfully. Data: 06:05:51 , 15
# Message published successfully. Data: 06:05:52 , 63
# Message published successfully. Data: 06:05:53 , 80
# Message published successfully. Data: 06:05:54 , 54
# Message published successfully. Data: 06:05:55 , 5
# Message published successfully. Data: 06:05:56 , 53
# Message published successfully. Data: 06:05:57 , 0
# Message published successfully. Data: 06:05:58 , 65
# Message published successfully. Data: 06:05:59 , 88
# Message published successfully. Data: 06:06:00 , 11
# Message published successfully. Data: 06:06:01 , 28
# Message published successfully. Data: 06:06:02 , 99
# Message published successfully. Data: 06:06:03 , 74
# Message published successfully. Data: 06:06:04 , 53
# Message published successfully. Data: 06:06:05 , 18
# Message published successfully. Data: 06:06:06 , 80
# Message published successfully. Data: 06:06:07 , 52
